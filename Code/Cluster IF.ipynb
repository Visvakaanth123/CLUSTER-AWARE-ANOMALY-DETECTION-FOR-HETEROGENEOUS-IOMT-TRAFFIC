# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest


scaler = StandardScaler()
dataset = pd.read_csv("infusion pump cluster.csv")
scaled_dataset = scaler.fit_transform(dataset)
model = IsolationForest(n_estimators=50,contamination="auto")
dataset = dataset.astype(float)

model.fit(scaled_dataset)

def simulate_flow(base_index, dataset, scaler, model, steps=15):
    base_flow = dataset.iloc[[base_index]].copy()
    stacked_flows = []

    flow = base_flow.copy()

    for i in range(steps):
        flow = flow.copy()

        flow.loc[:, "syn_count"] += 2 * (i + 1)
        flow.loc[:, "rst_count"] += 1.0 * (i + 1)
        flow.loc[:, "fin_count"] += 0.8 * (i + 1)
        flow.loc[:, "ack_count"] *= (0.95 ** (i + 1))

        stacked_flows.append(flow)

    stacked_df = pd.concat(stacked_flows, ignore_index=True)
    stacked_scaled = scaler.transform(stacked_df)

    predictions = model.predict(stacked_scaled)
    scores = model.decision_function(stacked_scaled)

    return predictions, scores

rows = [5, 18, 35, 57, 74, 92, 110, 145, 180, 215]

for idx in rows:
    print(f"\n==== Base flow iloc[{idx}] ====")
    preds, scores = simulate_flow(idx, dataset, scaler, model)

    for i, (p, s) in enumerate(zip(preds, scores)):
        print(f"Window {i+1}: pred= {p} , score= {s:.4f}")
# Out:
# ==== Base flow iloc[5] ====
# Window 1: pred= 1 , score= 0.0738
# Window 2: pred= 1 , score= 0.0048
# Window 3: pred= -1 , score= -0.0195
# Window 4: pred= -1 , score= -0.0195
# Window 5: pred= -1 , score= -0.0195
# Window 6: pred= -1 , score= -0.0195
# Window 7: pred= -1 , score= -0.0195
# Window 8: pred= -1 , score= -0.0195
# Window 9: pred= -1 , score= -0.0195
# Window 10: pred= -1 , score= -0.0282
# Window 11: pred= -1 , score= -0.0282
# Window 12: pred= -1 , score= -0.0282
# Window 13: pred= -1 , score= -0.0282
# Window 14: pred= -1 , score= -0.0282
# Window 15: pred= -1 , score= -0.0282
#
# ==== Base flow iloc[18] ====
# Window 1: pred= -1 , score= -0.0057
# Window 2: pred= -1 , score= -0.0789
# Window 3: pred= -1 , score= -0.0916
# Window 4: pred= -1 , score= -0.0916
# Window 5: pred= -1 , score= -0.0916
# Window 6: pred= -1 , score= -0.0916
# Window 7: pred= -1 , score= -0.0916
# Window 8: pred= -1 , score= -0.0916
# Window 9: pred= -1 , score= -0.0916
# Window 10: pred= -1 , score= -0.0916
# Window 11: pred= -1 , score= -0.0916
# Window 12: pred= -1 , score= -0.0916
# Window 13: pred= -1 , score= -0.0916
# Window 14: pred= -1 , score= -0.0916
# Window 15: pred= -1 , score= -0.0916
#
# ==== Base flow iloc[35] ====
# Window 1: pred= 1 , score= 0.0633
# Window 2: pred= -1 , score= -0.0119
# Window 3: pred= -1 , score= -0.0275
# Window 4: pred= -1 , score= -0.0275
# Window 5: pred= -1 , score= -0.0275
# Window 6: pred= -1 , score= -0.0275
# Window 7: pred= -1 , score= -0.0275
# Window 8: pred= -1 , score= -0.0275
# Window 9: pred= -1 , score= -0.0275
# Window 10: pred= -1 , score= -0.0363
# Window 11: pred= -1 , score= -0.0363
# Window 12: pred= -1 , score= -0.0363
# Window 13: pred= -1 , score= -0.0363
# Window 14: pred= -1 , score= -0.0363
# Window 15: pred= -1 , score= -0.0363
#
# ==== Base flow iloc[57] ====
# Window 1: pred= 1 , score= 0.0203
# Window 2: pred= -1 , score= -0.0602
# Window 3: pred= -1 , score= -0.0736
# Window 4: pred= -1 , score= -0.0736
# Window 5: pred= -1 , score= -0.0736
# Window 6: pred= -1 , score= -0.0736
# Window 7: pred= -1 , score= -0.0736
# Window 8: pred= -1 , score= -0.0736
# Window 9: pred= -1 , score= -0.0736
# Window 10: pred= -1 , score= -0.0736
# Window 11: pred= -1 , score= -0.0736
# Window 12: pred= -1 , score= -0.0736
# Window 13: pred= -1 , score= -0.0736
# Window 14: pred= -1 , score= -0.0736
# Window 15: pred= -1 , score= -0.0736
#
# ==== Base flow iloc[74] ====
# Window 1: pred= 1 , score= 0.0697
# Window 2: pred= -1 , score= -0.0063
# Window 3: pred= -1 , score= -0.0312
# Window 4: pred= -1 , score= -0.0312
# Window 5: pred= -1 , score= -0.0312
# Window 6: pred= -1 , score= -0.0312
# Window 7: pred= -1 , score= -0.0312
# Window 8: pred= -1 , score= -0.0312
# Window 9: pred= -1 , score= -0.0312
# Window 10: pred= -1 , score= -0.0400
# Window 11: pred= -1 , score= -0.0400
# Window 12: pred= -1 , score= -0.0400
# Window 13: pred= -1 , score= -0.0400
# Window 14: pred= -1 , score= -0.0400
# Window 15: pred= -1 , score= -0.0400
#
# ==== Base flow iloc[92] ====
# Window 1: pred= -1 , score= -0.0844
# Window 2: pred= -1 , score= -0.1396
# Window 3: pred= -1 , score= -0.1490
# Window 4: pred= -1 , score= -0.1490
# Window 5: pred= -1 , score= -0.1490
# Window 6: pred= -1 , score= -0.1490
# Window 7: pred= -1 , score= -0.1490
# Window 8: pred= -1 , score= -0.1490
# Window 9: pred= -1 , score= -0.1490
# Window 10: pred= -1 , score= -0.1598
# Window 11: pred= -1 , score= -0.1598
# Window 12: pred= -1 , score= -0.1598
# Window 13: pred= -1 , score= -0.1598
# Window 14: pred= -1 , score= -0.1598
# Window 15: pred= -1 , score= -0.1598
#
# ==== Base flow iloc[110] ====
# Window 1: pred= -1 , score= -0.1077
# Window 2: pred= -1 , score= -0.1528
# Window 3: pred= -1 , score= -0.1581
# Window 4: pred= -1 , score= -0.1581
# Window 5: pred= -1 , score= -0.1581
# Window 6: pred= -1 , score= -0.1581
# Window 7: pred= -1 , score= -0.1581
# Window 8: pred= -1 , score= -0.1581
# Window 9: pred= -1 , score= -0.1581
# Window 10: pred= -1 , score= -0.1581
# Window 11: pred= -1 , score= -0.1581
# Window 12: pred= -1 , score= -0.1581
# Window 13: pred= -1 , score= -0.1581
# Window 14: pred= -1 , score= -0.1581
# Window 15: pred= -1 , score= -0.1581
#
# ==== Base flow iloc[145] ====
# Window 1: pred= 1 , score= 0.0725
# Window 2: pred= 1 , score= 0.0026
# Window 3: pred= -1 , score= -0.0218
# Window 4: pred= -1 , score= -0.0218
# Window 5: pred= -1 , score= -0.0218
# Window 6: pred= -1 , score= -0.0218
# Window 7: pred= -1 , score= -0.0218
# Window 8: pred= -1 , score= -0.0218
# Window 9: pred= -1 , score= -0.0218
# Window 10: pred= -1 , score= -0.0305
# Window 11: pred= -1 , score= -0.0305
# Window 12: pred= -1 , score= -0.0305
# Window 13: pred= -1 , score= -0.0305
# Window 14: pred= -1 , score= -0.0305
# Window 15: pred= -1 , score= -0.0305
#
# ==== Base flow iloc[180] ====
# Window 1: pred= -1 , score= -0.0673
# Window 2: pred= -1 , score= -0.1222
# Window 3: pred= -1 , score= -0.1370
# Window 4: pred= -1 , score= -0.1370
# Window 5: pred= -1 , score= -0.1370
# Window 6: pred= -1 , score= -0.1370
# Window 7: pred= -1 , score= -0.1370
# Window 8: pred= -1 , score= -0.1370
# Window 9: pred= -1 , score= -0.1370
# Window 10: pred= -1 , score= -0.1370
# Window 11: pred= -1 , score= -0.1370
# Window 12: pred= -1 , score= -0.1370
# Window 13: pred= -1 , score= -0.1370
# Window 14: pred= -1 , score= -0.1370
# Window 15: pred= -1 , score= -0.1370
#
# ==== Base flow iloc[215] ====
# Window 1: pred= 1 , score= 0.0594
# Window 2: pred= -1 , score= -0.0142
# Window 3: pred= -1 , score= -0.0286
# Window 4: pred= -1 , score= -0.0286
# Window 5: pred= -1 , score= -0.0286
# Window 6: pred= -1 , score= -0.0286
# Window 7: pred= -1 , score= -0.0286
# Window 8: pred= -1 , score= -0.0286
# Window 9: pred= -1 , score= -0.0286
# Window 10: pred= -1 , score= -0.0374
# Window 11: pred= -1 , score= -0.0374
# Window 12: pred= -1 , score= -0.0374
# Window 13: pred= -1 , score= -0.0374
# Window 14: pred= -1 , score= -0.0374
# Window 15: pred= -1 , score= -0.0374
